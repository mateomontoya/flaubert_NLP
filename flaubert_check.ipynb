# %%
from bs4 import BeautifulSoup
from bs4.element import Comment
import re
import pandas as pd
import numpy as np
import nltk
import html5lib
import glob
import codecs
import os
import cltk

# %%
print ("The current working directory is", os.getcwd())
# Out:
# The current working directory is /Users/mateomontoya/Desktop/flaubert2/data

# %%
flaubert_data = pd.read_csv('parsed.csv')
len(flaubert_data)
# Out:
# 4494

# %%
flaubert_data.head(25)
# Out:
#     chapter folio                                            margins  \
# 0       NaN   NaN                                                NaN
# 1       NaN    2v                                                NaN
# 2       1.0     3  allait puis cela en dôme tendu à 2 1 c'était d...
# 3       1.0    3v  ce fut un vacarme suprême. on comme un flot dé...
# 4       1.0     4  de Rouen des moyens comme toujours ainsi que d...
# 5       1.0    4v   basses / bombés / Mais Puis 2 2 1 1 au-delà d...
# 6       1.0     5  entournures en bras apercevoir poignets ses au...
# 7       1.0    5v  à l'air ses l'auberge lorsqu'il quand de l'air...
# 8       1.0     6  ou en effet  au contraire dès le seuil de la p...
# 9       1.0    6v  Nonancourt un nouveau/vel élève Nor Martainvil...
# 10      1.0     7  petit croisillon un petit croisillon pr faire ...
# 11      1.0    7v  donc du plus loin il fallait au contraire pr ê...
# 12      1.0     8  ce d'accord isolées quoique les qui tombaient ...
# 13      NaN   NaN  suprême retomba d'accord à la fin tout qq temp...
# 14      1.0    8v  & et 3 1 2 d'accord sonore -universel éclats d...
# 15      1.0     9    qui ainsi qu'une enfin là et sans - qu'on pa...
# 16      1.0    9v  2 1 au bord des portes  la gde porte et au-des...
# 17      1.0    10   C'était chez le curé de son village qu'il ava...
# 18      1.0   10v    furibonde tout net & plus vite vraiment nouv...
# 19      1.0    11  robuste forte de santé rob (elle était maigre ...
# 20      1.0   11v   alors il & où il se mit trop qu'il vendait bo...
# 21      1.0    12   Elle était devenue en vieillissant, à la mani...
# 22      1.0   12v   Mais lent d'esprit & naturellement paisible, ...
# 23      1.0    13   Quand il était en colère  C'était la seule ma...
# 24      1.0   13v    une et {{ achevé son devoir examiner jusqu'a...
#
#                                     margins_no_struck  \
# 0                                                 NaN
# 1                                                 NaN
# 2   allait puis cela en dôme tendu à 2 1 c'était d...
# 3   ce fut un vacarme suprême. comme un flot débor...
# 4   de Rouen ainsi que d'usage chacun Mr Roger der...
# 5            basses / bombés / Puis 2 1 au-delà d' nu
# 6   entournures en bras apercevoir poignets ses au...
# 7   à l'air ses l'auberge lorsqu'il ouvertes en pa...
# 8   ou en effet au contraire dès le seuil de la po...
# 9   Nonancourt un nou /vel élève de lui méritoires...
# 10  petit croisillon pr faire & à côté près de lui...
# 11  du plus loin il fallait pr être convenable - d...
# 12  ce d'accord isolées quoique les qui tombaient ...
# 13  suprême retomba se calmant à gd peine à prtant...
# 14  & et 3 1 2 d'accord sonore -universel éclats d...
# 15  qui enfin là - qu'on il lui fut enjoint comme ...
# 16  1 la gde porte et au-dessus de l'auberge vieux...
# 17  C'était chez le curé de son village qu'il avai...
# 18  furibonde tout net & plus vite vraiment nouvel...
# 19  robuste forte de santé (elle était maigre on l...
# 20  & trop qu'il vendait bon marché & achetait tro...
# 21  Elle était devenue en vieillissant, à la maniè...
# 22  Mais lent d'esprit & naturellement paisible, l...
# 23  Quand il était en colère C'était la seule mani...
# 24  une et {{ achevé son devoir examiner jusqu'au ...
#
#                                        margins_struck  \
# 0                                                 NaN
# 1                                                 NaN
# 2   ement lâche qu'il présenta au maître d'études ...
# 3   on puis com par peut à m alors, comme une band...
# 19  Quoiqu'elle ne fût pas bien porta , Quoique dé...
# 20  8 Le beau père vint à mourir et laissa peu de ...
# 21  9 qui l'avaient détaché d'elle, encore plus . ...
# 22  10 durement pour en faire un homme , lui appre...
# 23  10. ils avaient pris l'habitude de se disputer...
# 24  7. de son pupitre, et pria un camarade son voi...
#
#                                    previous_no_struck  \
# 0            Madame Bovary ____________ 19 7bre 1851.
# 1         à Dieppe entendre des chanteurs Montagnards
# 2   Madame Bovary. I. Une heure et demie venaient ...
# 3   - ce fut un vacarme suprême - les rires ... et...
# 4   Madame Bovary I. Une heure et demie venaient d...
# 5   142 des fenêtres dont les gros carreaux verts ...
# 6   2. aux , / on voyait qu'il avait grandi dedans...
# 7   147 Depuis que les évènements que l'on va raco...
# 8   3. il fallait & le plus raide que l'on pouvait...
# 9   Voici Bovary de il entre en cinquième. Je vous...
# 10  4. /. - elle était neuve - la visière brillait...
# 11  il fallait pour être convenable en entrant en ...
# 12  Ce fut un vacarme suprême qui s'élança d'un se...
# 13  5 Ce fut un vacarme qui relança d'un bond mont...
# 14  sortait comme d'un étui deux jambes en bas ble...
# 15  5. Ce fut un vacarme suprême qui relança d'un ...
# 16  147 Depuis que les évènements que l'on va raco...
# 17  7 Il avait commencé le latin chez le curé de s...
# 18  6. voix furieuse, arrêta que le quos ego d'Eol...
# 19  Quoiqu'elle ne fût pas , Quoique délicate de l...
# 20  8 Le beau père vint à mourir et laissa peu de ...
# 21  9 qui l'avaient détaché d'elle, encore . c'éta...
# 22  10 durement , lui apprenant , quand il lui app...
# 23  10. ils avaient pris l'habitude de se disputer...
# 24  7. de son pupitre, son et régla soigneusement ...
#
#                                       previous_struck  \
# 0                                                 NaN
# 1                                                 NaN
# 2   trois et le maître d'études attendait le petit...
# 3   comme veut prendre laissé un on allait ce s*/r...
# 4   de Rouen comme toujours Mr Roger l'étude des j...
# 5   basses bombés la boutique d' . Puis les barrea...
# 6   emmanchures il serrées aux poignets poignets v...
# 7   encore au vent et en tombant vieux efflanqué t...
# 8   au contraire pr être convenable du plus dès la...
# 9   Mr Charles Norceuillers* dignes de ce que j'at...
# 10  petit croisillon un croisillon petite croix de...
# 11  le bon ton ne voulait pas qu'on eût de quoi qu...
# 12  d'accord d'abord d'accord, plein confus perçan...
# 13  seul tourbillon s'abattit roula se nt peu à pe...
# 14  quand pr tout à coup co sonore -universel un h...
# 15  qui à la fin et D en classe le censeur lui fut...
# 16  et le vieux d'or efflanqué qui tout cabré dans...
# 17  ne voul dans grande e cour de mur petit plein ...
# 18  plus bo qui avait peut-être qui sans qu'un voi...
# 19  bien porta elle allait, venait mouvement enten...
# 20  de vins & se mit à faire valoir de le v l'envo...
# 21  plus quand je l'ai conn une femme maigre d'av ...
# 22  pour en faire un homme à insulter les processi...
# 23  repro à avait se voulut en fair son père à la ...
# 24  et pria un camarade voisin de lui prêter un ca...
#
#                                                struck  \
# 0                                                 NaN
# 1                                                 NaN
# 2   ement lâche trois et le maître d'études attend...
# 3   on puis com par par peut à m alors, comme une ...
# 4   de Rouen de des moyens comme toujours comme to...
# 5   basses bombés la boutique d' Mais . Puis les b...
# 6   emmanchures il serrées aux poignets poignets v...
# 7   encore au vent  quand de l'air chatouille bala...
# 8    au contraire pr être convenable du plus dès l...
# 9   veau Nor Martainville Mr Charles Norceuillers*...
# 10  petit croisillon un petit croisillon un croisi...
# 11  donc au contraire son fort du plus loin de le ...
# 12  d'accord d'abord d'accord, plein confus perçan...
# 13  seul tourbillon d'accord à la fin tout qq temp...
# 14  quand pr tout à coup co sonore -universel un h...
# 15  qui ainsi qu'une à la fin et D et en classe sa...
# 16  2 au bord des portes et le vieux d'or efflanqu...
# 17  ne voul dans dégarnie grande e cour petit de m...
# 18  plus bo qui avait peut-être qui sans d/ qu' tr...
# 19  bien porta rob le président les chez elle fais...
# 20  alors il de vins & se mit où il se mit à faire...
# 21  devint elle était devenue avec l'âge à vivre s...
# 22  er/ lui pour en faire un homme et à insulter l...
# 23  elle repro ayant* les jours à avait résultat s...
# 24  et pria un camarade voisin de lui prêter un ca...
#
#                                                  text  \
# 0            Madame Bovary ____________ 19 7bre 1851.
# 1         à Dieppe entendre des chanteurs Montagnards
# 2   allait puis cela en dôme tendu à 2 1 c'était d...
# 3   ce fut un vacarme suprême. on comme un flot dé...
# 4   Madame Bovary I. de Rouen Une heure et demie v...
# 5   142 basses / bombés / des fenêtres basses dont...
# 6   2. entournures aux emmanchures, il/ on voyait ...
# 7   147 Depuis que les évènements que l'on va raco...
# 8   3. ou en effet au contraire dès le seuil de la...
# 9   Nonancourt un nouveau/vel élève Nor Martainvil...
# 10  4. petit croisillon un petit croisillon un cro...
# 11  donc du plus loin il fallait au contraire pr ê...
# 12  ce d'accord Ce fut d'abord un vacarme suprême ...
# 13  5 suprême Ce fut un vacarme qui relança d'un s...
# 14  sortait comme d'un étui deux jambes en bas ble...
# 15  5. Ce fut un vacarme suprême qui relança d'un ...
# 16  147 Depuis que les évènements que l'on va raco...
# 17  7 C'était chez le curé de son village qu'il av...
# 18  6. furibonde tout net & plus vite vraiment voi...
# 19  robuste Quoiqu'elle ne fût pas bien porta, for...
# 20  8 Le beau père vint à mourir et laissa peu de ...
# 21  Elle était devenue en vieillissant, à la maniè...
# 22  10 Mais lent d'esprit & naturellement paisible...
# 23  10. Quand il était en colère C'était la seule ...
# 24  7. de son pupitre, et pria un camarade son voi...
#
#                              underlined version
# 0                                   NaN       1
# 1                                   NaN       1
# 2            des moyens nouveau nouveau       1
# 3                                   NaN       1
# 4   des moyens nouveau et et le nouveau       1
# 5                                   NaN       1
# 6                              affaires       1
# 7                                allées       1
# 8                               nouveau       1
# 9                               nouveau       1
# 10                      nouveau nouveau       1
# 11                 chic nouveau nouveau       1
# 12                                  NaN       1
# 13                                  NaN       1
# 14                                  NaN       1
# 15                 ses auteurs quos ego       1
# 16                se sont allées portes       1
# 17                                pr pr       1
# 18   ridiculus sum pr ridiculus eram pr       1
# 19                         méritante au       1
# 20                                  NaN       1
# 21                            renfermée       1
# 22                                  NaN       1
# 23                                  qui       1
# 24                                  NaN       1

# %%
flaubert_data.describe()
# Out:
#            chapter
# count  4193.000000
# mean      6.787741
# std       5.632493
# min       1.000000
# 25%       4.000000
# 50%       7.000000
# 75%       9.000000
# max     288.000000

# %%
flaubert_data['chapter'].value_counts(dropna=False)
# Out:
# 8.0      680
# 5.0      461
# 6.0      415
# 1.0      403
# 9.0      401
# 7.0      348
# NaN      301
# 2.0      287
# 3.0      262
# 12.0     186
# 11.0     175
# 10.0     160
# 4.0      144
# 14.0     123
# 15.0      82
# 13.0      65
# 288.0      1
# Name: chapter, dtype: int64

# %%
flaubert_data['version'].value_counts(dropna=False)
# Out:
# 6    640
# 2    639
# 3    598
# 1    578
# 4    557
# 5    520
# C    491
# D    471
# Name: version, dtype: int64
